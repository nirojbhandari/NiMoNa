# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import networkx as nx

def rk4_step(f, x, pars, h):
    k1 = f(x, *pars)
    k2 = f(x + h/2*k1, *pars)
    k3 = f(x + h/2*k2, *pars)
    k4 = f(x + h*k3, *pars)
    return x + h/6*(k1 + 2*(k2+k3) + k4)
def rhs(x,d,u,alpha,gamma,b,A):
    res=-d*x+b+u*np.tanh(alpha*x+gamma*np.matmul(A,x))
    return res
N=15
x=np.zeros(N)
A=np.zeros((N,N))
def pars(d,u,alpha,gamma,b):
    return [d,u,alpha,gamma,b]
pars=[1,0.31,1.2,-1.3,0]
h=1e-3
Tend =10
t = 0

#circle
for i in range(N-1):
    A[i, i+1] = 1
    A[i+1, i] = 1
A[N-1, 0] = 1
A[0, N-1] = 1

# now get plot-positions
rows, cols = np.where(A == 1.)
edges = zip(rows.tolist(), cols.tolist())
gr = nx.Graph()
gr.add_edges_from(edges)
plot_positions = nx.drawing.spring_layout(gr)

# and create a colorbar
vmin = -2
vmax = 2
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
cmap = plt.get_cmap('coolwarm')
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
plt.colorbar(sm)

i = 4
nx.draw(gr, pos=plot_positions, node_size=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import networkx as nx

def rk4_step(f, x, pars, h):
    k1 = f(x, *pars)
    k2 = f(x + h/2*k1, *pars)
    k3 = f(x + h/2*k2, *pars)
    k4 = f(x + h*k3, *pars)
    return x + h/6*(k1 + 2*(k2+k3) + k4)
def rhs(x,d,u,alpha,gamma,b,A):
    res=-d*x+b+u*np.tanh(alpha*x+gamma*np.matmul(A,x))
    return res
N=15
x=np.zeros(N)
A=np.zeros((N,N))
def pars(d,u,alpha,gamma,b):
    return [d,u,alpha,gamma,b]
pars=[1,0.50,1.3,-5.5,0]
h=1e-3
Tend =10
t = 0

# wheel
for i in range(N-2):
    A[i, i+1] = 1
    A[i+1, i] = 1
    A[i, N-1] = 1
    A[N-1, i] = 1

A[N-2, N-1] = 1
A[N-1, N-2] = 1

A[N-2, 0] = 1
A[0, N-2] = 1


# now get plot-positions
rows, cols = np.where(A == 1.)
edges = zip(rows.tolist(), cols.tolist())
gr = nx.Graph()
gr.add_edges_from(edges)
plot_positions = nx.drawing.spring_layout(gr)

# and create a colorbar
vmin = -2
vmax = 2
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
cmap = plt.get_cmap('coolwarm')
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
plt.colorbar(sm)

i = 4
nx.draw(gr, pos=plot_positions, node_size=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import networkx as nx

def rk4_step(f, x, pars, h):
    k1 = f(x, *pars)
    k2 = f(x + h/2*k1, *pars)
    k3 = f(x + h/2*k2, *pars)
    k4 = f(x + h*k3, *pars)
    return x + h/6*(k1 + 2*(k2+k3) + k4)
def rhs(x,d,u,alpha,gamma,b,A):
    res=-d*x+b+u*np.tanh(alpha*x+gamma*np.matmul(A,x))
    return res
N=15
x=np.zeros(N)
A=np.zeros((N,N))
def pars(d,u,alpha,gamma,b):
    return [d,u,alpha,gamma,b]
pars=[1,0.31,1.2,-1.3,0]
h=1e-3
Tend =10
t = 0

#circle
for i in range(N-1):
    A[i, i+1] = 1
    A[i+1, i] = 1
A[N-1, 0] = 1
A[0, N-1] = 1
A[0,0]=0
# ======================================================================
# wheel
for i in range(N-2):
    A[i, i+1] = 1
    A[i+1, i] = 1
    A[i, N-1] = 1
    A[N-1, i] = 1

A[N-2, N-1] = 1
A[N-1, N-2] = 1

A[N-2, 0] = 1
A[0, N-2] = 1


# now get plot-positions
rows, cols = np.where(A == 1.)
edges = zip(rows.tolist(), cols.tolist())
gr = nx.Graph()
gr.add_edges_from(edges)
plot_positions = nx.drawing.spring_layout(gr)

# and create a colorbar
vmin = -2
vmax = 2
norm = mpl.colors.Normalize(vmin=vmin, vmax=vmax)
cmap = plt.get_cmap('coolwarm')
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
plt.colorbar(sm)

i = 4
nx.draw(gr, pos=plot_positions, node_size=500)
plt.savefig(f'picture_{i:07d}.png')
plt.show()
